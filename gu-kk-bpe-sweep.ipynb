# %%
import os
import re

# %%
import pandas as pd

# %%
results_path = 'evaluate/kk_gu_bpe_sweep/'

# %%
bpe_sweep_csv_names = os.listdir(results_path)

# %%
all_results = pd.DataFrame()

# %%
bpes = [1000, 2500, 1000, 7500, 10000]

# %%
for fname, bpe_size in zip(bpe_sweep_csv_names, bpes):
    df = pd.read_csv(f"{results_path}/{fname}")
    df['bpe_size'] = bpe_size
    all_results = pd.concat([all_results, df])

# %%
all_results['method'] = all_results.method.str.replace('baseline', 'sentencepiece')

# %%
all_results.groupby(["pair", "method", "bpe_size"]).bleu.describe().round(3)
# Out:
#                               count   mean    std  min   25%   50%  75%  max
# pair  method        bpe_size
# en-gu sentencepiece 1000        5.0  0.000  0.000  0.0  0.00  0.00  0.0  0.0
#                     2500        5.0  0.000  0.000  0.0  0.00  0.00  0.0  0.0
#                     7500        5.0  0.000  0.000  0.0  0.00  0.00  0.0  0.0
#                     10000       5.0  0.000  0.000  0.0  0.00  0.00  0.0  0.0
#       subword-nmt   1000        5.0  0.000  0.000  0.0  0.00  0.00  0.0  0.0
#                     2500        5.0  0.000  0.000  0.0  0.00  0.00  0.0  0.0
#                     7500        5.0  0.000  0.000  0.0  0.00  0.00  0.0  0.0
#                     10000       5.0  0.000  0.000  0.0  0.00  0.00  0.0  0.0
# en-kk sentencepiece 1000        5.0  1.180  0.084  1.1  1.10  1.20  1.2  1.3
#       subword-nmt   1000        5.0  0.500  0.071  0.4  0.50  0.50  0.5  0.6
# gu-en sentencepiece 1000        5.0  0.020  0.045  0.0  0.00  0.00  0.0  0.1
#                     2500        5.0  0.000  0.000  0.0  0.00  0.00  0.0  0.0
#                     7500        5.0  0.000  0.000  0.0  0.00  0.00  0.0  0.0
#                     10000       5.0  0.000  0.000  0.0  0.00  0.00  0.0  0.0
#       subword-nmt   1000        5.0  0.000  0.000  0.0  0.00  0.00  0.0  0.0
#                     2500        5.0  0.000  0.000  0.0  0.00  0.00  0.0  0.0
#                     7500        5.0  0.000  0.000  0.0  0.00  0.00  0.0  0.0
#                     10000       5.0  0.000  0.000  0.0  0.00  0.00  0.0  0.0
# kk-en sentencepiece 1000        3.0  2.067  0.058  2.0  2.05  2.10  2.1  2.1
#       subword-nmt   1000        4.0  1.550  0.058  1.5  1.50  1.55  1.6  1.6

# %%
all_results.groupby(["pair", "method", "bpe_size"]).chrf3.describe().round(3)*100
# Out:
#                               count  mean  std   min   25%   50%   75%   max
# pair  method        bpe_size
# en-gu sentencepiece 1000      500.0   1.6  0.4   1.2   1.4   1.4   2.1   2.1
#                     2500      500.0   1.1  0.2   0.8   1.0   1.1   1.3   1.4
#                     7500      500.0   1.2  0.3   0.8   0.9   1.1   1.4   1.6
#                     10000     500.0   1.6  1.0   0.8   0.8   1.4   1.6   3.2
#       subword-nmt   1000      500.0   2.2  0.3   1.8   2.0   2.3   2.4   2.6
#                     2500      500.0   1.5  0.1   1.4   1.4   1.5   1.6   1.7
#                     7500      500.0   1.1  0.6   0.3   0.7   1.1   1.4   1.8
#                     10000     500.0   1.3  0.6   0.7   0.7   1.4   1.6   2.1
# en-kk sentencepiece 1000      500.0  22.0  0.2  21.8  21.8  21.8  22.2  22.3
#       subword-nmt   1000      500.0  20.7  0.3  20.3  20.5  20.8  20.9  21.0
# gu-en sentencepiece 1000      500.0   4.6  2.7   2.1   2.7   3.4   6.4   8.3
#                     2500      500.0   2.4  1.1   1.2   1.6   2.5   2.9   4.0
#                     7500      500.0   0.9  0.9   0.3   0.4   0.5   0.7   2.4
#                     10000     500.0   2.1  0.3   1.7   2.0   2.3   2.3   2.4
#       subword-nmt   1000      500.0   5.9  0.8   4.7   5.6   6.0   6.1   7.0
#                     2500      500.0   4.8  1.9   1.6   5.0   5.3   5.6   6.5
#                     7500      500.0   5.0  1.3   3.1   4.5   4.9   6.0   6.4
#                     10000     500.0   4.8  1.2   3.4   4.5   4.6   4.9   6.6
# kk-en sentencepiece 1000      300.0  24.0  0.5  23.5  23.8  24.0  24.2  24.4
#       subword-nmt   1000      400.0  24.4  0.2  24.2  24.3  24.4  24.6  24.7
